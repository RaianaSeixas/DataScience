# %% [markdown]
# <a href="https://colab.research.google.com/github/RaianaSeixas/Python-/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Serie creation and description

prices = [42.8, 102.03, 240.38, 80.9] 
s = pd.Series(prices)
print(s.describe())
# Out:
# count      4.000000
# mean     116.527500
# std       86.129132
# min       42.800000
# 25%       71.375000
# 50%       91.465000
# 75%      136.617500
# max      240.380000
# dtype: float64

# %%
# DataFrame Creation

data = {
  'date': ['2021-06-10', '2021-06-11', '2021-06-12', '2021-06-13'],
  'prices': [42.8, 102.03, 240.38, 80.9]
}
df = pd.DataFrame(data)
print(df)
print(df.describe())
# Out:
#          date  prices
# 0  2021-06-10   42.80
# 1  2021-06-11  102.03
# 2  2021-06-12  240.38
# 3  2021-06-13   80.90
#            prices
# count    4.000000
# mean   116.527500
# std     86.129132
# min     42.800000
# 25%     71.375000
# 50%     91.465000
# 75%    136.617500
# max    240.380000
