# %% [markdown]
# <a href="https://colab.research.google.com/github/RaianaSeixas/DataScience/blob/main/Python/Estruturas_de_repeti%C3%A7%C3%A3o_e_outros_operadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Estruturas de repetição

# %%
lista_ativos = ['PETR4.SA', 'WEGE3.SA', 'MGLU3.SA', 'LREN3.SA', 'RENT3.SA', 'VALE3.SA']

# %%
for acao in lista_ativos:
  print(acao, ' é um ativo do IBOV')
  if acao=='RENT3.SA':
    break
# Out:
# PETR4.SA  é um ativo do IBOV
# WEGE3.SA  é um ativo do IBOV
# MGLU3.SA  é um ativo do IBOV
# LREN3.SA  é um ativo do IBOV
# RENT3.SA  é um ativo do IBOV

# %%
acao='PETR4'
INDEX = 0
for letra in acao:
 print("No índice", INDEX, "O caractere é ", letra)
 INDEX+=1
# Out:
# No índice 0 O caractere é  P
# No índice 1 O caractere é  E
# No índice 2 O caractere é  T
# No índice 3 O caractere é  R
# No índice 4 O caractere é  4

# %% [markdown]
# ###While
# A estrutura do while (enquanto, em português) se refere a outra repetição (loop) que ocorrerá enquanto a condição for
# verdadeira. Poderia ser pensada de uma maneira análoga ao uso do 'for' e 'if' integrados.

# %%
preco_weg = 30
while preco_weg < 39:
 print("Ainda não atingiu o preço alvo, espere. O preço atual é: ", round(preco_weg,2))
 preco_weg = preco_weg*1.1
else:
 print("Preço alvo atingido, hora de vender! Preço da venda: ", round(preco_weg, 2))
# Out:
# Ainda não atingiu o preço alvo, espere. O preço atual é:  30
# Ainda não atingiu o preço alvo, espere. O preço atual é:  33.0
# Ainda não atingiu o preço alvo, espere. O preço atual é:  36.3
# Preço alvo atingido, hora de vender! Preço da venda:  39.93

# %%
# Outro exemplo de uso do while. Imagine que tem disponível 10000 reais para investir. A cada operação, sera
# A função input interage com o usuario, recebendo um objeto (numérico, string...) e armazenando em uma variá
investimento_unitario = 0
investimento_total = 0

# Enquanto o valor alocado for menor que 10000 a condição do while será executada. Quando essa condição não f
while investimento_total < 10000:
 investimento_unitario = int(input("Digite o valor investido na operação: "))
 investimento_total = investimento_total + investimento_unitario
else:
 print("Limite total previsto para investir foi atingido!")
 print("Você excedeu ", investimento_total-10000, " do valor previsto")
print("Você investiu o total de R$", investimento_total)
# Out:
# Digite o valor investido na operação: 500
# Digite o valor investido na operação: 8000
# Digite o valor investido na operação: 2000
# Limite total previsto para investir foi atingido!
# Você excedeu  500  do valor previsto
# Você investiu o total de R$ 10500

# %% [markdown]
# # Outros operadores
#
# Enumerate

# %%
lista_ativos = ['PETR4.SA', 'WEGE3.SA', 'MGLU3.SA', 'LREN3.SA', 'RENT3.SA', 'VALE3.SA']

# %%
list(enumerate(lista_ativos))
# Out:
# [(0, 'PETR4.SA'),
#  (1, 'WEGE3.SA'),
#  (2, 'MGLU3.SA'),
#  (3, 'LREN3.SA'),
#  (4, 'RENT3.SA'),
#  (5, 'VALE3.SA')]

# %%
# Podemos começar a enumeração a partir de outro número que não o 0
list(enumerate(lista_ativos,3))
# Out:
# [(3, 'PETR4.SA'),
#  (4, 'WEGE3.SA'),
#  (5, 'MGLU3.SA'),
#  (6, 'LREN3.SA'),
#  (7, 'RENT3.SA'),
#  (8, 'VALE3.SA')]

# %% [markdown]
# #ZIP

# %%
acoes = ['PETR4', 'WEGE3', 'MGLU3', 'JHSF3', 'GOAU4']
setores = ['Petróleo', 'Motores', 'Varejo', 'Construção', 'Metalurgia']

# %%
list(zip(acoes, setores))
# Out:
# [('PETR4', 'Petróleo'),
#  ('WEGE3', 'Motores'),
#  ('MGLU3', 'Varejo'),
#  ('JHSF3', 'Construção'),
#  ('GOAU4', 'Metalurgia')]

# %%
for i,j in list(zip(acoes,setores)):
  print('O papel', i, 'pertence ao setor', j)
# Out:
# O papel PETR4 pertence ao setor Petróleo
# O papel WEGE3 pertence ao setor Motores
# O papel MGLU3 pertence ao setor Varejo
# O papel JHSF3 pertence ao setor Construção
# O papel GOAU4 pertence ao setor Metalurgia

# %% [markdown]
# ## Random

# %%
import random
rlist=[]
for i in range(1,10):
  rlist.append(random.randint(100,200))

print(rlist)
# Out:
# [185, 154, 114, 179, 144, 177, 181, 160, 176]

# %%
random.shuffle(rlist)

# %%
rlist
# Out:
# [179, 114, 160, 176, 154, 185, 144, 177, 181]

# %%
min(rlist)
# Out:
# 114

# %%
max(rlist)
# Out:
# 185

# %% [markdown]
# Input and print properties

# %%
acao=input('Insira a ação que deseja comprar ')
print(f'O cliente deseja comprar {acao} ')
# Out:
# Insira a ação que deseja comprar ENEV3
# O cliente deseja comprar ENEV3

# %% [markdown]
# ## Compreenção de lista

# %%
acao='PETR4'
[char for char in acao]
# Out:
# ['P', 'E', 'T', 'R', '4']

# %%
'''
Imagine que você recebeu uma série de tickers que vieram incompletos. Antes de realizar sua rotina, precisa adicionar um
número '3' aos nomes dos papéis. Como você faria?
'''

ativos = ['MGLU', 'VALE', 'WEGE', 'LREN']

# %%
new=[]
for letra in ativos:
  new.append(letra+'3')

new
# Out:
# ['MGLU3', 'VALE3', 'WEGE3', 'LREN3']

# %%
'''
Podemos realizar essa tarefa com uma compreensão de lista de uma forma mais rápida.
'''
[letra+str(3)for letra in ativos]
# Out:
# ['MGLU3', 'VALE3', 'WEGE3', 'LREN3']

# %%
#Imagine que quiséssemos elevar todos os números de 0 a 10 ao quadrado.

[num**2 for num in range(0,11)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# # Funções e Métodos
# ## Criando Docstring da função

# %%
def preco(acao):

  ''' ESSA FUNÇÃO DEVE SER UTILIZADA PARA RETORNAR A COTAÇÃO EM TEMPO REAL DE UM PAPEL '''
  if (acao == 'PETR4'):
    print('O preço agora é R$ 30,89')
  elif (acao == 'VALE3'):
    print('O preço agora é R$ 112')
  elif (acao == 'WEGE3'):
    print('O preço agora é R$ 32')
  elif (acao == 'MGLU3'):
    print('O preço agora é R$ 24,59')
  else:
    print('Papel desconhecido')

# %%
help(preco)
# Out:
# Help on function preco in module __main__:
#
# preco(acao)
#     ESSA FUNÇÃO DEVE SER UTILIZADA PARA RETORNAR A COTAÇÃO EM TEMPO REAL DE UM PAPEL

# %% [markdown]
# ## MAP
#
# A função map() aplica um comando (função) a vários elementos de uma lista, de uma vez

# %%
def potencia(num, pot = 2):
 return num**pot

# %%
potencia(3,4)
# Out:
# 81

# %%
potencia (3)
# Out:
# 9

# %%
numer=[1,2,3,4,5]
list(map(potencia, numer))
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Filter
# De forma análoga, a função "filter" aplica um filtro a vários elementos de uma lista de uma só vez.

# %%
def checkint(x):
  return x%2==0

# %%
list(filter(checkint, numer)) # vai retornar apenas os valores da lista que obedecem o critério da função
# Out:
# [2, 4]
